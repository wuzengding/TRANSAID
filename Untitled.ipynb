# %%
install.packages("ggseqlogo")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
# 加载所需的包
library(ggseqlogo)
library(ggplot2) 
# 模拟一组Kozak序列数据（实际中替换为真实的Kozak序列）
kozak_sequences <- c("GCCAUGG", "GCCAUGA", "GCCAUGC")

# 使用ggseqlogo绘制Sequence logo图
ggseqlogo(kozak_sequences) +
  labs(title = "Kozak Sequence Logo",
       x = "Position",
       y = "Bits") +
  theme_minimal()
# Out:
# plot without title

# %%
# 加载所需的包
library(ggseqlogo)
library(ggplot2)

# 构建PWM矩阵
kozak_pwm <- matrix(c(
  # A    C    G    T
  0.22, 0.28, 0.32, 0.18,  # -6
  0.20, 0.30, 0.30, 0.20,  # -5
  0.18, 0.32, 0.30, 0.20,  # -4
  0.25, 0.15, 0.45, 0.15,  # -3
  0.20, 0.35, 0.25, 0.20,  # -2
  0.20, 0.35, 0.25, 0.20,  # -1
  1.00, 0.00, 0.00, 0.00,  # 0 (A of ATG)
  0.00, 0.00, 0.00, 1.00,  # 1 (T of ATG)
  0.00, 0.00, 1.00, 0.00,  # 2 (G of ATG)
  0.20, 0.20, 0.40, 0.20   # 3
), byrow = TRUE, nrow = 10)

# 转换矩阵为数据框格式
pfm_df <- as.data.frame(kozak_pwm)
colnames(pfm_df) <- c("A", "C", "G", "T")

# 使用ggseqlogo的makeMatrix函数创建PWM对象
pwm <- t(as.matrix(pfm_df))

# 绘制序列logo
p <- ggseqlogo(pwm, method="prob") +
  labs(title = "Kozak Sequence Logo",
       x = "Position",
       y = "Probability") +
  scale_x_continuous(breaks = 1:10,
                    labels = c(-6:-1, 0:3)) +
  ylim(0, 1) +
  theme_minimal() +
  theme(
    plot.title = element_text(hjust = 0.5, face = "bold", size = 14),
    axis.text = element_text(size = 10),
    axis.title = element_text(size = 12),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank()
  )

# 显示图形
print(p)
# Out:
# Scale for x is already present.
# Adding another scale for x, which will replace the existing scale.
# plot without title

# %%
# 加载所需的包
if (!requireNamespace("svglite", quietly = TRUE)) {
    install.packages("svglite")
}
library(svglite)
library(ggseqlogo)
library(ggplot2)

# 构建PWM矩阵
kozak_pwm <- matrix(c(
  # A    C    G    T
  0.22, 0.28, 0.32, 0.18,  # -6
  0.20, 0.30, 0.30, 0.20,  # -5
  0.18, 0.32, 0.30, 0.20,  # -4
  0.25, 0.15, 0.45, 0.15,  # -3
  0.20, 0.35, 0.25, 0.20,  # -2
  0.20, 0.35, 0.25, 0.20,  # -1
  1.00, 0.00, 0.00, 0.00,  # 0 (A of ATG)
  0.00, 0.00, 0.00, 1.00,  # 1 (T of ATG)
  0.00, 0.00, 1.00, 0.00,  # 2 (G of ATG)
  0.20, 0.20, 0.40, 0.20   # 3
), byrow = TRUE, nrow = 10)

# 转换矩阵为数据框格式
pfm_df <- as.data.frame(kozak_pwm)
colnames(pfm_df) <- c("A", "C", "G", "T")

# 使用ggseqlogo的makeMatrix函数创建PWM对象
pwm <- t(as.matrix(pfm_df))

# 绘制序列logo
p <- ggseqlogo(pwm, method="prob") +
  theme_void() +  # 移除所有轴线、标签等
  ylim(0, 1) +
  theme(
    plot.margin = margin(0, 0, 0, 0)  # 移除边距
  )

# 保存为SVG格式
ggsave("kozak_logo.svg", p, width = 8, height = 4, units = "in")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
